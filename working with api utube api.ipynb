# %%
##import liabraries
import requests
import pandas as pd
import time

# %%
##keys
API_KEY = 'AIzaSyCiso_y9uExTLXM9HpvlTB_DTSuT-XTfuM'
CHANNEL_ID = 'UCRBKQn-nNSj_MB90bhp8tWA'

# %%
##make api call
#testing request liabrary
#grabing data from github api
response=requests.get('https://api.github.com').json()##passes as a string in single quote
##json to give format of data will return,you should definitly know how to work with this json objects
response
# Out:
# {'authorizations_url': 'https://api.github.com/authorizations',
#  'code_search_url': 'https://api.github.com/search/code?q={query}{&page,per_page,sort,order}',
#  'commit_search_url': 'https://api.github.com/search/commits?q={query}{&page,per_page,sort,order}',
#  'current_user_authorizations_html_url': 'https://github.com/settings/connections/applications{/client_id}',
#  'current_user_repositories_url': 'https://api.github.com/user/repos{?type,page,per_page,sort}',
#  'current_user_url': 'https://api.github.com/user',
#  'emails_url': 'https://api.github.com/user/emails',
#  'emojis_url': 'https://api.github.com/emojis',
#  'events_url': 'https://api.github.com/events',
#  'feeds_url': 'https://api.github.com/feeds',
#  'followers_url': 'https://api.github.com/user/followers',
#  'following_url': 'https://api.github.com/user/following{/target}',
#  'gists_url': 'https://api.github.com/gists{/gist_id}',
#  'hub_url': 'https://api.github.com/hub',
# ...

# %% [markdown]
# i want calculation and analytics of number of views and vedieos and according to my requirements i have to choose which parameter i have to pass through requests **here i need to pass part parameter**

# %%
##LETS WORK WITH UTUBE API
pageToken=''
url="https://www.googleapis.com/youtube/v3/search?key="+API_KEY+"&channelId="+CHANNEL_ID+"&part=snippet,id&order=date&maxResults=10000"+pageToken ##bulding url
response =requests.get(url).json()##all above code you have to explore from documentation

# %%
response ##required info output
# Out:
# {'etag': 'F0ffnYSb1yEgHa5Y0CgNOZYEExY',
#  'items': [{'etag': '33k3HUZ6tqiH3PmESBrLM2H6ppI',
#    'id': {'kind': 'youtube#video', 'videoId': 'GHETU_vQjCo'},
#    'kind': 'youtube#searchResult',
#    'snippet': {'channelId': 'UCRBKQn-nNSj_MB90bhp8tWA',
#     'channelTitle': 'Shubham jadhav',
#     'description': 'please subscribe my channel and support me it gives me motivation Copyright Disclaimer Copyright Disclaimer under ...',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-07-09T15:27:31Z',
#     'publishedAt': '2021-07-09T15:27:31Z',
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/GHETU_vQjCo/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/GHETU_vQjCo/hqdefault.jpg',
#       'width': 480},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/GHETU_vQjCo/mqdefault.jpg',
#       'width': 320}},
# ...

# %%
response['items']##get items info you can abstractb any info by pssing value to reeponse
# Out:
# [{'etag': '33k3HUZ6tqiH3PmESBrLM2H6ppI',
#   'id': {'kind': 'youtube#video', 'videoId': 'GHETU_vQjCo'},
#   'kind': 'youtube#searchResult',
#   'snippet': {'channelId': 'UCRBKQn-nNSj_MB90bhp8tWA',
#    'channelTitle': 'Shubham jadhav',
#    'description': 'please subscribe my channel and support me it gives me motivation Copyright Disclaimer Copyright Disclaimer under ...',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2021-07-09T15:27:31Z',
#    'publishedAt': '2021-07-09T15:27:31Z',
#    'thumbnails': {'default': {'height': 90,
#      'url': 'https://i.ytimg.com/vi/GHETU_vQjCo/default.jpg',
#      'width': 120},
#     'high': {'height': 360,
#      'url': 'https://i.ytimg.com/vi/GHETU_vQjCo/hqdefault.jpg',
#      'width': 480},
#     'medium': {'height': 180,
#      'url': 'https://i.ytimg.com/vi/GHETU_vQjCo/mqdefault.jpg',
#      'width': 320}},
#    'title': 'Good night whatsapp status||ankho se chulu❤️'}},
#  {'etag': 'Q--IF95jhMfiKYgp3Wc4Oymu22U',
# ...

# %%
##parsing thrpugh the data
#get the first vedieo
response['items'][0]##0 gives index number that is first element of items column
# Out:
# {'etag': '33k3HUZ6tqiH3PmESBrLM2H6ppI',
#  'id': {'kind': 'youtube#video', 'videoId': 'GHETU_vQjCo'},
#  'kind': 'youtube#searchResult',
#  'snippet': {'channelId': 'UCRBKQn-nNSj_MB90bhp8tWA',
#   'channelTitle': 'Shubham jadhav',
#   'description': 'please subscribe my channel and support me it gives me motivation Copyright Disclaimer Copyright Disclaimer under ...',
#   'liveBroadcastContent': 'none',
#   'publishTime': '2021-07-09T15:27:31Z',
#   'publishedAt': '2021-07-09T15:27:31Z',
#   'thumbnails': {'default': {'height': 90,
#     'url': 'https://i.ytimg.com/vi/GHETU_vQjCo/default.jpg',
#     'width': 120},
#    'high': {'height': 360,
#     'url': 'https://i.ytimg.com/vi/GHETU_vQjCo/hqdefault.jpg',
#     'width': 480},
#    'medium': {'height': 180,
#     'url': 'https://i.ytimg.com/vi/GHETU_vQjCo/mqdefault.jpg',
#     'width': 320}},
#   'title': 'Good night whatsapp status||ankho se chulu❤️'}}

# %% [markdown]
# ##save vedieo id

# %%
response['items'][0]['id']['videoId']##extract vedieo id name and store it as variable videoId
# Out:
# 'GHETU_vQjCo'

# %%
##grab title of vedieo saved in snippit key
video_title=response['items'][0]['snippet']['title']
video_title=str(video_title).replace("&amp;","")

# %%
video_title
# Out:
# 'Good night whatsapp status||ankho se chulu❤️'

# %%
upload_date=response['items'][0]['snippet']['publishedAt']
upload_date
# Out:
# '2021-07-09T15:27:31Z'

# %%
#save the date and throw out time zone
upload_date = str(upload_date).split("T")[0]
upload_date
# Out:
# '2021-07-09'

# %%
##now we have to collect all this information for each video
#1.lets grab all data in one place
#2.create for loop
for video in response['items']:
  if video ['id']['kind']  =="youtube#video":
    video_id=video['id']['videoId']
    video_title=video['snippet']['title']
    video_title=str(video_title).replace("&amp;","")
    upload_date=video['snippet']['publishedAt']
    upload_date = str(upload_date).split("T")[0]
    print(video_id)
    print(video_title)
    print(upload_date)
# Out:
# GHETU_vQjCo
# Good night whatsapp status||ankho se chulu❤️
# 2021-07-09
# 5H-H3o6eLvk
# sai pallavi and WWE remix whatsapp status 😍😍||mera chain vain sab ujda status
# 2021-05-23
# ZfegOYf3g5U
# sai pallavi whatsapp status 2021 new||sai pallavi status vedieo
# 2021-05-22
# JyEUDpIcJso
# WWE roman Reigns best whatsapp status 😍 ||WWE best whatsapp status new
# 2021-05-20
# 7nA1aO03igs
# deul band marathi movie best status vedieo||swami samarth|| laksh purvak bagh🙏🙏
# 2021-05-10
# WG252ZaZEoM
# don&#39;t judge book by it&#39;s cover||boys attitude  whatsapp status
# 2021-05-01
# KT_jj9qx_C0
# best crush status || best love whatsapp status ||❤️😍😍🤩
# 2021-04-30
# qqt64xaJZFo
# best boys attitude status||best crush whatsapp status 😍😍🤩😎😎🤓
# 2021-04-30
# Pz6Br-8Wors
# best love status❤️❤️❤️
# 2021-03-28
# PBnObKhO1PM
# suryaputra karn best status||shri krishna seekh
# 2021-03-05
# 2jU78i6SRbY
# leagend of hanuman best scene||hanuman go to lanka
# 2021-03-03
# wN-lO_VBdEI
# ...

# %%
##collecting all these info is good but not great so what great is,dislikes,commnt count etc.
##2nd api call
url_video_stats ="https://www.googleapis.com/youtube/v3/videos?id="+video_id+"&part=statistics&key="+API_KEY
response_video_stats=requests.get(url_video_stats).json()
view_count =response_video_stats['items'][0]['statistics']['viewCount']
like_count =response_video_stats['items'][0]['statistics']['likeCount']

comment_count =response_video_stats['items'][0]['statistics']['commentCount']

# %%
##build pandas dataframe
df=pd.DataFrame(columns=["video_id","video_title","upload_date","view_count","like_count","comment_count"])

# %%
##lets put it into for loop
for video in response['items']:
  if video ['id']['kind']  =="youtube#video":
    video_id=video['id']['videoId']
    video_title=video['snippet']['title']
    video_title=str(video_title).replace("&amp;","")
    upload_date=video['snippet']['publishedAt']
    upload_date = str(upload_date).split("T")[0]
    
    ##collecting view etc.
    url_video_stats ="https://www.googleapis.com/youtube/v3/videos?id="+video_id+"&part=statistics&key="+API_KEY
    response_video_stats=requests.get(url_video_stats).json()
    view_count =response_video_stats['items'][0]['statistics']['viewCount']
    like_count =response_video_stats['items'][0]['statistics']['likeCount']

    comment_count =response_video_stats['items'][0]['statistics']['commentCount']
    ##save data in padas dframe
    df=df.append({'video_id':video_id,'video_title':video_title
                  ,'upload_date':upload_date,'view_count':view_count,'like_count':like_count,
                  'comment_count':comment_count},ignore_index=True)

# %%
df.head()
# Out:
#       video_id  ... comment_count
# 0  GHETU_vQjCo  ...             0
# 1  5H-H3o6eLvk  ...             0
# 2  ZfegOYf3g5U  ...             1
# 3  JyEUDpIcJso  ...             0
# 4  7nA1aO03igs  ...             3
#
# [5 rows x 6 columns]

# %% [markdown]
# implimenting good software enginneering fundamental

# %%
def get_video_details(video_id):
    url_video_stats ="https://www.googleapis.com/youtube/v3/videos?id="+video_id+"&part=statistics&key="+API_KEY
    response_video_stats=requests.get(url_video_stats).json()
    view_count =response_video_stats['items'][0]['statistics']['viewCount']
    like_count =response_video_stats['items'][0]['statistics']['likeCount']
    return view_count,like_count,comment_count

# %%
def get_videos(df):
  #make api call
  pageToken=''
  url="https://www.googleapis.com/youtube/v3/search?key="+API_KEY+"&channelId="+CHANNEL_ID+"&part=snippet,id&order=date&maxResults=10000"+pageToken ##bulding url
  response =requests.get(url).json()
  time.sleep(1)##take some rest before jumping into for loop
  for video in response['items']:
     if video ['id']['kind']  =="youtube#video":
         video_id=video['id']['videoId']
         video_title=video['snippet']['title']
         video_title=str(video_title).replace("&amp;","")
         upload_date=video['snippet']['publishedAt']
         upload_date = str(upload_date).split("T")[0]
         view_count,like_count,comment_count=get_video_details(video_id)
         ##save data in padas dframe
         df=df.append({'video_id':video_id,'video_title':video_title
                  ,'upload_date':upload_date,'view_count':view_count,'like_count':like_count,
                  'comment_count':comment_count},ignore_index=True)
  return df

# %%
df=get_videos(df)
df
# Out:
#        video_id  ... comment_count
# 0   GHETU_vQjCo  ...             0
# 1   5H-H3o6eLvk  ...             0
# 2   ZfegOYf3g5U  ...             1
# 3   JyEUDpIcJso  ...             0
# 4   7nA1aO03igs  ...             3
# ..          ...  ...           ...
# 71  0T2Zqm9WxaM  ...             2
# 72  CQ8OCB5DIe8  ...             2
# 73  4_1PODxT_nE  ...             2
# 74  Ji3ta4OpJcA  ...             2
# 75  Z1qhhdACW-A  ...             2
#
# [76 rows x 6 columns]
